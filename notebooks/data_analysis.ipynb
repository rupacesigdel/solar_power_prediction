# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("../data/processed/super_master_dataset.csv")

df.head()
# Out:
#           timestamp  avg_air_temp  avg_global_rad  avg_cell_rad  \
# 0  01-01-2023 00:00      9.610000        0.000000      0.295000
# 1  01-01-2023 01:00      9.737143        0.000000      0.252143
# 2  01-01-2023 02:00      9.590714        0.008571      0.270000
# 3  01-01-2023 03:00      9.907143        0.308571      0.274286
# 4  01-01-2023 04:00      9.793571        0.258571      0.302143
#
#    avg_surface_temp  avg_wind_speed  irradiance_avg  ITS_Energy (kWh)  hour  \
# 0          8.427143             0.0        0.000000               0.0     0
# 1          8.762143             0.0        0.011190               0.0     1
# 2          8.515714             0.0        0.033095               0.0     2
# 3          9.815000             0.0        0.380714               0.0     3
# 4          9.839286             0.0        0.286190               0.0     4
#
#    day  month  year
# 0    1      1  2023
# 1    1      1  2023
# 2    1      1  2023
# 3    1      1  2023
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19276 entries, 0 to 19275
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   timestamp         19276 non-null  str
#  1   avg_air_temp      19276 non-null  float64
#  2   avg_global_rad    19276 non-null  float64
#  3   avg_cell_rad      19276 non-null  float64
#  4   avg_surface_temp  19276 non-null  float64
#  5   avg_wind_speed    19276 non-null  float64
#  6   irradiance_avg    19276 non-null  float64
#  7   ITS_Energy (kWh)  19276 non-null  float64
#  8   hour              19276 non-null  int64
#  9   day               19276 non-null  int64
#  10  month             19276 non-null  int64
#  11  year              19276 non-null  int64
# dtypes: float64(7), int64(4), str(1)
# memory usage: 1.8 MB

# %%
df.isnull().sum()
# Out:
# timestamp           0
# avg_air_temp        0
# avg_global_rad      0
# avg_cell_rad        0
# avg_surface_temp    0
# avg_wind_speed      0
# irradiance_avg      0
# ITS_Energy (kWh)    0
# hour                0
# day                 0
# month               0
# year                0
# dtype: int64

# %%
df.describe()
# Out:
#        avg_air_temp  avg_global_rad  avg_cell_rad  avg_surface_temp  \
# count  19276.000000    19276.000000  19276.000000      1.927600e+04
# mean      22.324903      184.792163    171.454042      1.105743e+09
# std        6.710555      261.706781    243.392564      1.085759e+11
# min        5.033571        0.000000      0.005000     -4.485786e+01
# 25%       17.265000        0.000000      0.147857      1.721857e+01
# 50%       23.181786       55.429286     63.844286      2.446929e+01
# 75%       26.875179      319.528571    291.504107      3.589911e+01
# max       38.886429     2564.481429   3545.910714      1.421430e+13
#
#        avg_wind_speed  irradiance_avg  ITS_Energy (kWh)          hour  \
# count    19276.000000    19276.000000      19276.000000  19276.000000
# mean         0.632357      195.828803      46477.306838     11.499274
# std          0.789463      271.287948      44022.301144      6.925915
# min          0.000000        0.000000          0.000000      0.000000
# ...

# %%
# Correlation Heatmap
plt.figure(figsize=(14,10))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm'
)

plt.title("Feature Correlation Heatmap")

plt.show()

# %%
# Energy Production Trend
plt.figure(figsize=(16,5))

plt.plot(df['ITS_Energy (kWh)'])

plt.title("Solar Energy Production Trend")

plt.xlabel("Time")

plt.ylabel("ITS Energy (kWh)")

plt.show()

# %%
# Radiation Distribution
plt.figure(figsize=(8,5))

plt.hist(df['avg_global_rad'], bins=50)

plt.title("Global Radiation Distribution")

plt.xlabel("Radiation")

plt.ylabel("Frequency")

plt.show()

# %%
# Temperature vs Energy
plt.figure(figsize=(8,5))

plt.scatter(
    df['avg_air_temp'],
    df['ITS_Energy (kWh)'],
    alpha=0.3
)

plt.title("Temperature vs Energy")

plt.xlabel("Temperature")

plt.ylabel("Energy")

plt.show()
